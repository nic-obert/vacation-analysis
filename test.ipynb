# %%
import pandas as pd

# %%
df = pd.read_csv('data.csv')

# %%
df
# Out:
#                       Timestamp        What's your age? What's your gender?  \
# 0    2022/09/15 10:55:33 am EET       16 - 18 years old                Male
# 1    2022/09/15 11:02:53 am EET       16 - 18 years old                Male
# 2    2022/09/15 11:04:05 am EET       16 - 18 years old                Male
# 3    2022/09/15 11:11:53 am EET       18 - 25 years old         Non binary
# 4    2022/09/15 11:28:37 am EET       18 - 25 years old                Male
# ..                          ...                     ...                 ...
# 180   2022/09/15 8:01:34 pm EET       16 - 18 years old              Female
# 181   2022/09/15 8:01:50 pm EET       18 - 25 years old                Male
# 182   2022/09/15 8:06:04 pm EET  More than 25 years old              Female
# 183   2022/09/15 8:06:10 pm EET  More than 25 years old              Female
# 184   2022/09/15 8:06:57 pm EET       18 - 25 years old              Female
#
#     Where do you live?  \
# 0       Western Europe
# ...

# %%
print("hello world")
# Out:
# hello world

# %%
df.head()
# Out:
#                     Timestamp   What's your age? What's your gender?  \
# 0  2022/09/15 10:55:33 am EET  16 - 18 years old                Male
# 1  2022/09/15 11:02:53 am EET  16 - 18 years old                Male
# 2  2022/09/15 11:04:05 am EET  16 - 18 years old                Male
# 3  2022/09/15 11:11:53 am EET  18 - 25 years old         Non binary
# 4  2022/09/15 11:28:37 am EET  18 - 25 years old                Male
#
#   Where do you live?  \
# 0     Western Europe
# 1     Western Europe
# 2          Australia
# 3     Western Europe
# 4     Western Europe
#
#   Where do you usually enjoy your holidays? Select all that apply.  \
# 0                                  Seaside;Mountains
# 1                    Seaside;Mountains;Lake or river
# 2                                 Countryside;Cities
# 3                                  Seaside;Mountains
# 4                                  Seaside;Mountains
#
#   When on vacation, where do you usually stay? Select all that apply.  \
# ...

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3629, in Index.get_loc(self, key, method, tolerance)
#    3628 try:
# -> 3629     return self._engine.get_loc(casted_key)
#    3630 except KeyError as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.local/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
questions = df.keys()

# %%
questions
# Out:
# Index(['Timestamp', 'What's your age?', 'What's your gender?',
#        'Where do you live?',
#        'Where do you usually enjoy your holidays? Select all that apply.',
#        'When on vacation, where do you usually stay? Select all that apply.',
#        'Who do you usually enjoy your holidays with? Select all that apply.',
#        'What activities best describe your typical summer vacation? Select all that apply.',
#        'How do you choose where to go on vacation? Select all that apply.',
#        'What means of transport do you normally take when going on vacation? Select all that apply.',
#        'How much did you spend in total during your last summer holidays? Use this format: <cost> <currency> (e.g. 350 €)',
#        'How much did you enjoy your last summer vacation?',
#        'Thank you for your participation. If you want to receive the survey results, enter your email address here. We won't share your email address with anyone, nor send you any ads.'],
# ...

# %%
questions[0]
# Out:
# 'Timestamp'
